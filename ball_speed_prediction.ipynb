# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from dataprep.eda import create_report
from pycaret.regression import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('data/final_dataframe.pkl')
df.head()

# %%
model = setup(data = df, target = 'speed', silent=True, session_id=123, normalize = True)
# Out:
# <style type="text/css">
# #T_9c42d_row27_col1, #T_9c42d_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9c42d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c42d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9c42d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c42d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c42d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9c42d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9c42d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c42d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9c42d_row1_col1" class="data row1 col1" >speed</td>
#     </tr>
#     <tr>
#       <th id="T_9c42d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_9cbe6 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best, plot='feature')
# Out:
# Visual Rendered Successfully
# plot_model() succesfully completed......................................

# %%
model = setup(data = df, target = 'speed', session_id=123, silent=True,
                  normalize = True, transformation = True, transform_target = True, 
                  combine_rare_levels = True, rare_level_threshold = 0.05,
                  remove_multicollinearity = True, multicollinearity_threshold = 0.95)
# Out:
# <style type="text/css">
# #T_8fe63_row27_col1, #T_8fe63_row29_col1, #T_8fe63_row35_col1, #T_8fe63_row40_col1, #T_8fe63_row42_col1, #T_8fe63_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8fe63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fe63_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8fe63_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fe63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fe63_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8fe63_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8fe63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fe63_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8fe63_row1_col1" class="data row1 col1" >speed</td>
#     </tr>
#     <tr>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_f8f71 th {
#   text-align: left;
# }
# ...

# %%
et = create_model('et', fold = 5, round=2)
# Out:
# <style type="text/css">
# #T_d28d8_row5_col0, #T_d28d8_row5_col1, #T_d28d8_row5_col2, #T_d28d8_row5_col3, #T_d28d8_row5_col4, #T_d28d8_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d28d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d28d8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d28d8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d28d8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d28d8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d28d8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d28d8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_et = tune_model(et)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tuned_et = tune_model(et)
#
# NameError: name 'et' is not defined

# %%
plot_model(tuned_et, plot='feature')

# %%
plot_model(tuned_et, plot = 'error')

# %%
model = setup(data=df, target='speed', silent=True, session_id=123, normalize=True, 
              normalize_method='minmax', remove_multicollinearity = True, multicollinearity_threshold = 0.6, feature_selection = True, ignore_features = ['key'])

# %%
best = compare_models()

# %%
et = create_model('et')

# %%
tuned_et = tune_model(et)

# %%
print(tuned_et)

# %%
plot_model(tuned_et, plot='feature')

# %%
plot_model(tuned_et)

# %%
plot_model(tuned_et, plot = 'error')

# %%
plot_model(tuned_et, plot='feature_all')
